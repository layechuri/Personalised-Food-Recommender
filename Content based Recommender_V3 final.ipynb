# %%
# Code for recommender
# Input files - Food DB;  User Interaction Log; Cluster_mapping
# Output - a personalised recommnedation for the customer

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler

# %%
# read dish database
df = pd.read_json('Food DB.json')

# read userlog
orders = pd.read_excel('User Interaction Log.xlsx')

# read user clusters
usercluster = pd.read_csv('Cluster_mapping.csv')
usercluster.drop(usercluster.iloc[:, 1:47], axis = 1, inplace = True)
df
# Out:
#                                               Name  \
# 0           Himachali Dry Raw Mango Chutney Recipe
# 1      Aamras Ki Kadhi Recipe - Mango Kadhi Recipe
# 2                       Acorn Squash Sambal Recipe
# 3                   Kerala Palada Pradhaman Recipe
# 4                             Agathi Keerai Recipe
# ...                                            ...
# 7215                                   Gatta curry
# 7216                                        Khaman
# 7217                                     Paniyaram
# 7218                                         Lassi
# 7219  lemon honey glazed sous vide corn on the cob
#
#                                             description  \
# 0     Aam Papad (Sun Dried Mango)|Mint Leaves (Pudin...
# 1     Aamras|Gram flour (besan)|Turmeric powder (Hal...
# 2     Acorn Squash|Sambal paste|Turmeric powder (Hal...
# 3              Ada|Milk|Sugar|Cardamom Powder (Elaichi)
# 4     Agathi keerai|Yellow Moong Dal (Split)|Cumin s...
# ...                                                 ...
# 7215  Yogurt, besan, sauce, garam masala powder, gra...
# 7216  Yogurt, fresh coconut, sesame seeds, semolina,...
# 7217  Yogurt, ginger, curry leaves, baking soda, gre...
# 7218                          Yogurt, milk, nuts, sugar
# 7219  young corn on the cob, honey, lemon juice, gar...
#
#                                 sub_catagory Veg_Non    Review  \
# 0                             Indian Chutney     veg  4.909474
# 1                               Indian Curry     veg  4.873846
# 2                           Continental Food     veg  4.936475
# 3     Sweet Recipes (Indian Mithai / Indian      veg  4.901949
# 4                            Poriyal Recipes     veg  4.919255
# ...                                      ...     ...       ...
# 7215                                   Sabzi     veg  4.000000
# 7216                            Indian Snack     veg  4.000000
# 7217                            Indian Snack     veg  4.000000
# 7218                               Smoothies     veg  4.000000
# 7219   Continental Party Appetizer & Starter     veg  4.000000
#
#                     Cusine            Diet  Price  \
# 0                 Himachal      Vegetarian    475
# 1        Gujarati Recipes﻿      Vegetarian    337
# 2                    Asian  Non Vegeterian    513
# 3           Kerala Recipes      Vegetarian    461
# 4     South Indian Recipes      Vegetarian    383
# ...                    ...             ...    ...
# 7215                Indian      Vegetarian    579
# 7216                Indian      Vegetarian    327
# 7217  South Indian Recipes      Vegetarian    503
# 7218                Indian      Vegetarian    333
# 7219           Continental      Vegetarian    221
#
#                                        ingredients_list  \
# 0     [aam papad (sun dried mango), mint leaves (pud...
# 1     [aamras, gram flour (besan), turmeric powder (...
# 2     [acorn squash, sambal paste, turmeric powder (...
# 3         [ada, milk, sugar, cardamom powder (elaichi)]
# 4     [agathi keerai, yellow moong dal (split), cumi...
# ...                                                 ...
# 7215  [yogurt, besan, sauce, garam masala powder, gr...
# 7216  [yogurt, fresh coconut, sesame seeds, semolina...
# 7217  [yogurt, ginger, curry leaves, baking soda, gr...
# 7218                        [yogurt, milk, nuts, sugar]
# 7219  [young corn on the cob, honey, lemon juice, ga...
#
#                                                 Allergy  \
# 0     [Oral Allergy Syndrome, Sugar Allergy / Intole...
# 1                   [Legume Allergy, Histamine Allergy]
# 2     [Histamine Allergy, Allium Allergy, Peanut All...
# 3     [Milk allergy / Lactose intolerance, Sugar All...
# 4                                                    []
# ...                                                 ...
# 7215               [Milk allergy / Lactose intolerance]
# 7216  [Milk allergy / Lactose intolerance, Seed Alle...
# 7217  [Milk allergy / Lactose intolerance, Histamine...
# 7218  [Milk allergy / Lactose intolerance, Nut Aller...
# 7219  [Corn Allergy, Honey Allergy, Citrus Allergy, ...
#
#                                                Nutrient  \
# 0                                     [, carbs, sodium]
# 1                                    [, copper, sodium]
# 2                        [protien, , vitamin_E, sodium]
# 3                                  [, vitamin_D, carbs]
# 4     [calcium, , copper, manganese, vitamin_E, sodium]
# ...                                                 ...
# 7215                                        [calcium, ]
# 7216                     [calcium, manganese, copper, ]
# 7217                                        [calcium, ]
# 7218             [calcium, vitamin_D, vitamin_E, carbs]
# 7219                     [protien, , vitamin_C, sodium]
#
#                                       Disease (Bad for)        Category  \
# 0     [, Diabetes,Obesity,Heart-related ailments,PCO...       Side dish
# 1                                    [, Blood pressure]  Lunch / Dinner
# 2                   [, High Cholestrol, Blood pressure]  Lunch / Dinner
# 3      [, Diabetes,Obesity,Heart-related ailments,PCOD]         Dessert
# 4                   [, High Cholestrol, Blood pressure]       Breakfast
# ...                                                 ...             ...
# 7215                                                 []  Lunch / Dinner
# 7216                                                 []  Tea time snack
# 7217                                                 []  Tea time snack
# 7218  [, High Cholestrol, Diabetes,Obesity,Heart-rel...         Dessert
# 7219                                 [, Blood pressure]       Appetizer
#
#                 Season                     Mood
# 0            no season             Salt craving
# 1            no season                   Hungry
# 2     School vacations                   Hungry
# 3     Diwali, Dusshera  Sweet Craving,Celebrate
# 4            no season           Healthy eating
# ...                ...                      ...
# 7215         no season           Healthy eating
# 7216  School vacations                    Bored
# 7217  School vacations                    Bored
# 7218            Summer   Stressed,Sweet Craving
# 7219            Diwali                Celebrate
#
# [7220 rows x 15 columns]

# %%
std_scaler = StandardScaler() 
df[['Scaled prices']] = StandardScaler().fit_transform(df[['Price']])
# Out:
#                                               Name  \
# 0           Himachali Dry Raw Mango Chutney Recipe
# 1      Aamras Ki Kadhi Recipe - Mango Kadhi Recipe
# 2                       Acorn Squash Sambal Recipe
# 3                   Kerala Palada Pradhaman Recipe
# 4                             Agathi Keerai Recipe
# ...                                            ...
# 7215                                   Gatta curry
# 7216                                        Khaman
# 7217                                     Paniyaram
# 7218                                         Lassi
# 7219  lemon honey glazed sous vide corn on the cob
#
#                                             description  \
# 0     Aam Papad (Sun Dried Mango)|Mint Leaves (Pudin...
# 1     Aamras|Gram flour (besan)|Turmeric powder (Hal...
# 2     Acorn Squash|Sambal paste|Turmeric powder (Hal...
# 3              Ada|Milk|Sugar|Cardamom Powder (Elaichi)
# 4     Agathi keerai|Yellow Moong Dal (Split)|Cumin s...
# ...                                                 ...
# 7215  Yogurt, besan, sauce, garam masala powder, gra...
# 7216  Yogurt, fresh coconut, sesame seeds, semolina,...
# 7217  Yogurt, ginger, curry leaves, baking soda, gre...
# 7218                          Yogurt, milk, nuts, sugar
# 7219  young corn on the cob, honey, lemon juice, gar...
#
#                                 sub_catagory Veg_Non    Review  \
# 0                             Indian Chutney     veg  4.909474
# 1                               Indian Curry     veg  4.873846
# 2                           Continental Food     veg  4.936475
# 3     Sweet Recipes (Indian Mithai / Indian      veg  4.901949
# 4                            Poriyal Recipes     veg  4.919255
# ...                                      ...     ...       ...
# 7215                                   Sabzi     veg  4.000000
# 7216                            Indian Snack     veg  4.000000
# 7217                            Indian Snack     veg  4.000000
# 7218                               Smoothies     veg  4.000000
# 7219   Continental Party Appetizer & Starter     veg  4.000000
#
#                     Cusine            Diet  Price  \
# 0                 Himachal      Vegetarian    475
# 1        Gujarati Recipes﻿      Vegetarian    337
# 2                    Asian  Non Vegeterian    513
# 3           Kerala Recipes      Vegetarian    461
# 4     South Indian Recipes      Vegetarian    383
# ...                    ...             ...    ...
# 7215                Indian      Vegetarian    579
# 7216                Indian      Vegetarian    327
# 7217  South Indian Recipes      Vegetarian    503
# 7218                Indian      Vegetarian    333
# 7219           Continental      Vegetarian    221
#
#                                        ingredients_list  \
# 0     [aam papad (sun dried mango), mint leaves (pud...
# 1     [aamras, gram flour (besan), turmeric powder (...
# 2     [acorn squash, sambal paste, turmeric powder (...
# 3         [ada, milk, sugar, cardamom powder (elaichi)]
# 4     [agathi keerai, yellow moong dal (split), cumi...
# ...                                                 ...
# 7215  [yogurt, besan, sauce, garam masala powder, gr...
# 7216  [yogurt, fresh coconut, sesame seeds, semolina...
# 7217  [yogurt, ginger, curry leaves, baking soda, gr...
# 7218                        [yogurt, milk, nuts, sugar]
# 7219  [young corn on the cob, honey, lemon juice, ga...
#
#                                                 Allergy  \
# 0     [Oral Allergy Syndrome, Sugar Allergy / Intole...
# 1                   [Legume Allergy, Histamine Allergy]
# 2     [Histamine Allergy, Allium Allergy, Peanut All...
# 3     [Milk allergy / Lactose intolerance, Sugar All...
# 4                                                    []
# ...                                                 ...
# 7215               [Milk allergy / Lactose intolerance]
# 7216  [Milk allergy / Lactose intolerance, Seed Alle...
# 7217  [Milk allergy / Lactose intolerance, Histamine...
# 7218  [Milk allergy / Lactose intolerance, Nut Aller...
# 7219  [Corn Allergy, Honey Allergy, Citrus Allergy, ...
#
#                                                Nutrient  \
# 0                                     [, carbs, sodium]
# 1                                    [, copper, sodium]
# 2                        [protien, , vitamin_E, sodium]
# 3                                  [, vitamin_D, carbs]
# 4     [calcium, , copper, manganese, vitamin_E, sodium]
# ...                                                 ...
# 7215                                        [calcium, ]
# 7216                     [calcium, manganese, copper, ]
# 7217                                        [calcium, ]
# 7218             [calcium, vitamin_D, vitamin_E, carbs]
# 7219                     [protien, , vitamin_C, sodium]
#
#                                       Disease (Bad for)        Category  \
# 0     [, Diabetes,Obesity,Heart-related ailments,PCO...       Side dish
# 1                                    [, Blood pressure]  Lunch / Dinner
# 2                   [, High Cholestrol, Blood pressure]  Lunch / Dinner
# 3      [, Diabetes,Obesity,Heart-related ailments,PCOD]         Dessert
# 4                   [, High Cholestrol, Blood pressure]       Breakfast
# ...                                                 ...             ...
# 7215                                                 []  Lunch / Dinner
# 7216                                                 []  Tea time snack
# 7217                                                 []  Tea time snack
# 7218  [, High Cholestrol, Diabetes,Obesity,Heart-rel...         Dessert
# 7219                                 [, Blood pressure]       Appetizer
#
#                 Season                     Mood  Scaled prices  Score
# 0            no season             Salt craving       0.654438    0.0
# 1            no season                   Hungry      -0.552671    3.0
# 2     School vacations                   Hungry       0.986831    3.0
# 3     Diwali, Dusshera  Sweet Craving,Celebrate       0.531978    5.0
# 4            no season           Healthy eating      -0.150301    2.0
# ...                ...                      ...            ...    ...
# 7215         no season           Healthy eating       1.564144    0.0
# 7216  School vacations                    Bored      -0.640142    0.0
# 7217  School vacations                    Bored       0.899359    0.0
# 7218            Summer   Stressed,Sweet Craving      -0.587659    0.0
# 7219            Diwali                Celebrate      -1.567342    0.0
#
# [7220 rows x 17 columns]

# %%
# make a list of all users by cluster
cluster_zero = pd.pivot(usercluster, columns="cluster", values = 'User_ID')[0].dropna().tolist()
cluster_one = pd.pivot(usercluster, columns="cluster", values = 'User_ID')[1].dropna().tolist()
cluster_two = pd.pivot(usercluster, columns="cluster", values = 'User_ID')[2].dropna().tolist()

def get_user_cluster(current_user):
    if current_user in cluster_zero:
        return 0
    else:
        if current_user in cluster_one:
            return 1
        else:
            return 2

# map cluster to userlog data
orders = pd.merge(orders,usercluster, how='left', left_on='User_ID', right_on='User_ID')

cluster_zero_dishes = pd.pivot(orders, columns="cluster", values = 'Name')[0].dropna().tolist()
cluster_one_dishes = pd.pivot(orders, columns="cluster", values = 'Name')[1].dropna().tolist()
cluster_two_dishes = pd.pivot(orders, columns="cluster", values = 'Name')[2].dropna().tolist()


def get_my_dishes(current_user_cluster):
    if current_user_cluster == 0:
        return cluster_zero_dishes
    else:
        if current_user_cluster == 1:
            return cluster_one_dishes
        else: 
            return cluster_two_dishes

# %%
# determine popularity Scores based on user interactions
orders['Score'] = orders['Searched'] + orders['Purchased'] + orders['Liked'] 
user_interaction_count = orders.groupby('Name')['Score'].sum().reset_index()
df = pd.merge(df,user_interaction_count, how='left', left_on='Name', right_on='Name')
df['Score'].fillna(0, inplace=True)

# %%
# Average Reviews of all items
C= df['Review'].mean()

# Min votes required to appear in recommendation list fixed at 60% among 'Score'
m= df['Score'].quantile(0.6)

# shortlist dishes above 60%ile votes
q_items = df.copy().loc[df['Score'] >= m]

# Calculation of weighted rating based on the IMDB formula
def weighted_rating(x, m=m, C=C):
    v = x['Score']
    R = x['Review']
    return (v/(v+m) * R) + (m/(m+v) * C ) + x['Scaled prices']/1000

# Applying weighted_rating to qualified items
q_items['weighted_score'] = q_items.apply(weighted_rating, axis=1)

# Shortlisting the top rated items and popular items
top_rated_items = q_items.sort_values('weighted_score', ascending=False)
pop_items= df.sort_values('Score', ascending=False)
top_rated_items
# Out:
#                                                    Name  \
# 5541  White Chocolate Pistachio Bars Recipe | White ...
# 764                                Bathua Raita Recipe
# 1685             Chicken Souvlaki with Tzatziki Recipe
# 5902  Whole Wheat Methi Garlic Naan Recipe  | Oven M...
# 314   Homemade Tagliatelle Pasta with Capers and Bel...
# ...                                                 ...
# 7008                                    lamb rogan josh
# 6994                                     koldil chicken
# 6903                        oat crusted chicken tenders
# 6912                                     Chicken razala
# 6371  Lugai Gosht Recipe - Mutton In Spicy Tomato On...
#
#                                             description      sub_catagory  \
# 5541  White Chocolate|Butter (unsalted)|Condensed Mi...           Dessert
# 764   Bathua leaves|Green Chillies|Ginger|Black Salt...      Indian Curry
# 1685  Chicken breasts|Extra Virgin Olive Oil|Lemon j...  Continental Food
# 5902  Whole Wheat Flour|Salt|Sugar|Garlic|Methi Leav...      Indian Bread
# 314   All Purpose Flour (Maida)|Whole Wheat Flour|Wh...           Italian
# ...                                                 ...               ...
# 7008  lamb chops or stewing lamb, vegetable oil, cas...      Indian Snack
# 6994           ith banana flower; an assamese specialty  Continental Food
# 6903  chicken breast (cut into strips), salt, garlic...      Indian Snack
# 6912  Chicken, dahi, sesame seeds, garam masala powd...  Continental Food
# 6371  Mutton|Onion|Tomato|Sunflower Oil|Cardamom (El...             Sabzi
#
#       Veg_Non    Review                Cusine                         Diet  \
# 5541      veg  5.000000           Continental                   Vegetarian
# 764       veg  5.000000  North Indian Recipes            Diabetic Friendly
# 1685  non-veg  4.980392                 Greek  High Protein Non Vegetarian
# 5902      veg  4.979198  North Indian Recipes                   Vegetarian
# 314       veg  4.994135       Italian Recipes                   Vegetarian
# ...       ...       ...                   ...                          ...
# 7008      veg  4.000000                Indian                   Vegetarian
# 6994      veg  4.000000                Indian                   Vegetarian
# 6903  non-veg  4.000000           Continental                   Vegetarian
# 6912  non-veg  4.000000                Indian               Non Vegeterian
# 6371  non-veg  3.175705  North Indian Recipes               Non Vegeterian
#
#       Price                                   ingredients_list  \
# 5541    452  [white chocolate, butter (unsalted), condensed...
# 764     503  [bathua leaves, green chillies, ginger, black ...
# 1685    429  [chicken breasts, extra virgin olive oil, lemo...
# 5902    352  [whole wheat flour, salt, sugar, garlic, methi...
# 314     456  [all purpose flour (maida), whole wheat flour,...
# ...     ...                                                ...
# 7008    264  [lamb chops or stewing lamb, vegetable oil, ca...
# 6994    247         [ith banana flower; an assamese specialty]
# 6903    596  [chicken breast (cut into strips), salt, garli...
# 6912    362  [chicken, dahi, sesame seeds, garam masala pow...
# 6371    568  [mutton, onion, tomato, sunflower oil, cardamo...
#
#                                                 Allergy  \
# 5541               [Milk allergy / Lactose intolerance]
# 764                                 [Histamine Allergy]
# 1685  [Poultry Allergy, Citrus Allergy, Allium Aller...
# 5902  [Gluten Allergy, Sugar Allergy / Intolerance, ...
# 314                    [Gluten Allergy, Allium Allergy]
# ...                                                 ...
# 7008  [Allium Allergy, Milk allergy / Lactose intole...
# 6994                                   [Banana Allergy]
# 6903  [Poultry Allergy, Allium Allergy, Histamine Al...
# 6912                    [Poultry Allergy, Seed Allergy]
# 6371  [Allium Allergy, Nightshade Allergy, Histamine...
#
#                                                Nutrient  \
# 5541            [maginesum, sodium, vitamin_D, protien]
# 764                               [, sodium, vitamin_E]
# 1685    [iron, vitamin_E, vitamin_C, , sodium, calcium]
# 5902                       [carbs, sodium, , vitamin_E]
# 314   [carbs, vitamin_A, sodium, vitamin_E, , vitami...
# ...                                                 ...
# 7008      [iron, vitamin_E, , carbs, vitamin_C, sodium]
# 6994                                         [selenium]
# 6903                          [iron, sodium, , protien]
# 6912                        [iron, , copper, vitamin_E]
# 6371  [protien, , vitamin_C, vitamin_E, copper, sodium]
#
#                                       Disease (Bad for)        Category  \
# 5541                                 [, Blood pressure]         Dessert
# 764                 [, Blood pressure, High Cholestrol]  Lunch / Dinner
# 1685                [, High Cholestrol, Blood pressure]  Lunch / Dinner
# 5902  [Diabetes,Obesity,Heart-related ailments,PCOD,...  Lunch / Dinner
# 314   [Diabetes,Obesity,Heart-related ailments,PCOD,...  Lunch / Dinner
# ...                                                 ...             ...
# 7008  [, High Cholestrol, Diabetes,Obesity,Heart-rel...  Tea time snack
# 6994                                                 []  Lunch / Dinner
# 6903                                 [, Blood pressure]  Tea time snack
# 6912                                [, High Cholestrol]  Lunch / Dinner
# 6371                [, High Cholestrol, Blood pressure]  Lunch / Dinner
#
#                 Season                     Mood  Scaled prices  Score  \
# 5541            Summer  Sweet Craving,Celebrate       0.453253    6.0
# 764          no season                   Hungry       0.899359    5.0
# 1685  School vacations                   Hungry       0.252069    8.0
# 5902         no season           Healthy eating      -0.421463    8.0
# 314                IPL                    Bored       0.488242    5.0
# ...                ...                      ...            ...    ...
# 7008  School vacations                    Bored      -1.191214    8.0
# 6994  School vacations                   Hungry      -1.339916    8.0
# 6903  School vacations                    Bored       1.712845   11.0
# 6912  School vacations                   Hungry      -0.333992   11.0
# 6371         no season           Healthy eating       1.467925    5.0
#
#       weighted_score
# 5541        4.956985
# 764         4.951221
# 1685        4.949791
# 5902        4.948162
# 314         4.946621
# ...              ...
# 7008        4.164034
# 6994        4.163885
# 6903        4.128809
# 6912        4.126762
# 6371        3.648722
#
# [3486 rows x 18 columns]

# %%
# Creating soup string for each item
def create_soup(x):            
    tags = x['Name'].lower().split(', ')
    tags.extend(x['Category'].lower().split())
    tags.extend(x['sub_catagory'].lower().split())
    tags.extend(x['Cusine'].lower().split())
    tags.extend(x['Season'].lower().split())
    tags.extend(x['Mood'].lower().split())
    tags.extend(x['Diet'].lower().split())
    tags.extend(x['Veg_Non'].lower().split())
    return " ".join(sorted(set(tags), key=tags.index))

df['soup'] = df.apply(create_soup, axis=1)

# %%
# create count matrix and apply cosine similarity on it
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df1['soup'])
cosine_sim = cosine_similarity(count_matrix, count_matrix)

indices_from_title = pd.Series(df.index, index=df['Name'])

# %%
# Function that takes in Name of dish and outputs 10 most similar dishes 
def get_recommendations(title="", cosine_sim=cosine_sim, idx=-1):
    if idx == -1 and title != "":
        idx = indices_from_title[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:6] # change to how many every dishes you would want recommended by name
    food_indices = [i[0] for i in sim_scores]
    return food_indices

# test the code with a random dish
df.loc[get_recommendations(title="Tomato Chutney Recipe")]
# Out:
#                                                    Name  \
# 5327                          Raw Tomato Chutney Recipe
# 2367               Roasted Garlic Tomato Chutney Recipe
# 1028                              Brahmi Chutney Recipe
# 5355  Tomato Onion Chutney Recipe - Thakkali Vengaya...
# 3769  Tomato Onion Chutney Recipe With Coconut And Mint
#
#                                             description    sub_catagory  \
# 5327  Tomatoes|Green Chillies|Garlic|Methi Seeds (Fe...  Indian Chutney
# 2367  Garlic|Tomato|Dry Red Chilli|Tamarind|Sunflowe...  Indian Chutney
# 1028  Brahmi leaves|Fresh coconut|White Urad Dal (Sp...  Indian Chutney
# 5355  Tomatoes|Pearl onions (Sambar Onions)|Green Ch...  Indian Chutney
# 3769  Onions|Tomatoes|Green Chillies|Mint Leaves (Pu...  Indian Chutney
#
#      Veg_Non    Review                Cusine        Diet  \
# 5327     veg  4.913400  South Indian Recipes  Vegetarian
# 2367     veg  4.923077  South Indian Recipes  Vegetarian
# 1028     veg  4.899351  South Indian Recipes  Vegetarian
# 5355     veg  4.875684  South Indian Recipes  Vegetarian
# 3769     veg  4.647856  South Indian Recipes  Vegetarian
#
#                                        ingredients_list  \
# 5327  [tomatoes, green chillies, garlic, methi seeds...
# 2367  [garlic, tomato, dry red chilli, tamarind, sun...
# 1028  [brahmi leaves, fresh coconut, white urad dal ...
# 5355  [tomatoes, pearl onions (sambar onions), green...
# 3769  [onions, tomatoes, green chillies, mint leaves...
#
#                                                 Allergy  \
# 5327               [Nightshade Allergy, Allium Allergy]
# 2367               [Allium Allergy, Nightshade Allergy]
# 1028                                   [Legume Allergy]
# 5355  [Nightshade Allergy, Allium Allergy, Seed Alle...
# 3769               [Allium Allergy, Nightshade Allergy]
#
#                                                Nutrient  \
# 5327           [vitamin_C, , copper, sodium, vitamin_E]
# 2367           [, vitamin_C, vitamin_E, sodium, copper]
# 1028                   [, manganese, sodium, vitamin_E]
# 5355           [vitamin_C, , vitamin_E, sodium, copper]
# 3769  [, vitamin_C, manganese, copper, vitamin_E, so...
#
#                         Disease (Bad for)   Category     Season          Mood  \
# 5327  [, Blood pressure, High Cholestrol]  Side dish  no season  Salt craving
# 2367  [, High Cholestrol, Blood pressure]  Side dish  no season  Salt craving
# 1028  [, Blood pressure, High Cholestrol]  Side dish  no season  Salt craving
# 5355  [, High Cholestrol, Blood pressure]  Side dish  no season  Salt craving
# 3769  [, High Cholestrol, Blood pressure]  Side dish  no season  Salt craving
#
#       Score                                               soup
# 5327    0.0  raw tomato chutney recipe side dish indian chu...
# 2367    6.0  roasted garlic tomato chutney recipe side dish...
# 1028    0.0  brahmi chutney recipe side dish indian chutney...
# 5355    0.0  tomato onion chutney recipe - thakkali vengaya...
# 3769    2.0  tomato onion chutney recipe with coconut and m...

# %%
# Function to recommend based on past orders
def get_latest_user_orders(user_id, orders, num_orders=1):
    counter = num_orders
    order_indices = []
    
    for index, row in orders[['User_ID']].iterrows():
        if row.User_ID == user_id:
            counter = counter -1
            order_indices.append(index)
        if counter == 0:
            break        
    return order_indices

# %%
# return food_indices for accomplishing personalized recommendation using Count Vectorizer
def personalised_recomms(orders, df1, user_id, columns, comment="Based on your past orders"):
    order_indices = get_latest_user_orders(user_id, orders)
    food_ids = []
    recomm_indices = []
    
    for i in order_indices:
        food_ids.append(orders.loc[i].Name)
    for i in food_ids:
        recomm_indices.extend(get_recommendations(title=i))
        
    return get_recomms_df(set(recomm_indices), df1, columns, comment)


# fetch items from previously calculated top_rated_items list
def get_top_rated_items(top_rated_items, df1, columns,current_user ,comment="Top rated dishes by similar users"):
    current_user_cluster = get_user_cluster(current_user)
    my_dishes = get_my_dishes(current_user_cluster)
    food_indices = []
    
    for index, row in top_rated_items.head(20).iterrows():
        food_indices.append(indices_from_title[top_rated_items.loc[index].Name])
    
    food_indices_final = []
    
    # remove items that are not in our cluster
    for i in food_indices:
        dishname = df.iloc[i].Name
        if dishname in my_dishes:
            food_indices_final.append(i)
    
    return get_recomms_df(food_indices_final, df1, columns, comment)

# fetch items from previously calculated pop_items list
def get_popular_items(pop_items, df1, columns, current_user ,comment="Popular dishes among similar users"):
    current_user_cluster = get_user_cluster(current_user)
    food_indices = []
    for index, row in pop_items.iterrows():
        food_indices.append(indices_from_title[pop_items.loc[index].Name])
    
    # remove items that are not in our cluster
    for i in food_indices:
        dishname = df.iloc[i].Name
        if dishname in my_dishes:
            food_indices_final.append(i)
    
    return get_recomms_df(food_indices_final, df1, columns, comment)

# %%
# utility function to return df given recipie Name
def get_recomms_df(food_indices, df1, columns, comment):
    row = 0
    df = pd.DataFrame(columns=columns)
    
    for i in food_indices:
        df.loc[row] = df1[['Name', 'Category', 'sub_catagory', 'Cusine', 'Diet', 'Review']].loc[i]
        df.loc[row].comment = comment
        row = row+1
    return df

# %%
columns = ['Name', 'sub_catagory', 'Cusine', 'Diet','comment']
current_user = 66

# %%
personalised_recomms(orders, df, current_user, columns)
# Out:
#                                                 Name sub_catagory  \
# 0           Low Fat Apple Crumble with Muesli Recipe      Dessert
# 1  Whole Wheat And Ragi Crepe With Muesli And Str...      Dessert
# 2               Figs and Muesli Bread Pudding Recipe      Dessert
# 3                              Chocolate Tart Recipe      Dessert
# 4     8 Ingredient Sugar Free Granola Parfait Recipe      Dessert
#
#         Cusine             Diet                    comment
# 0  Continental  Sugar Free Diet  Based on your past orders
# 1  Continental  Sugar Free Diet  Based on your past orders
# 2  Continental  Sugar Free Diet  Based on your past orders
# 3  Continental       Eggetarian  Based on your past orders
# 4  Continental  Sugar Free Diet  Based on your past orders

# %%
get_top_rated_items(top_rated_items, df, columns,current_user).head(5)
# Out:
#                                                 Name      sub_catagory  \
# 0  White Chocolate Pistachio Bars Recipe | White ...           Dessert
# 1             Chicken Souvlaki with Tzatziki Recipe   Continental Food
# 2  Broccoli Chilli Noodles With Grilled Salmon Re...    Indian Chinese
# 3  Summer Salad with Goat Cream Cheese, Apricots ...             Salad
# 4                            Dhungare Baingan Recipe      Indian Curry
#
#         Cusine                         Diet                            comment
# 0  Continental                   Vegetarian  Top rated dishes by similar users
# 1        Greek  High Protein Non Vegetarian  Top rated dishes by similar users
# 2       Fusion                   Vegetarian  Top rated dishes by similar users
# 3  Continental                   Vegetarian  Top rated dishes by similar users
# 4     Lucknowi                   Vegetarian  Top rated dishes by similar users

# %%
get_popular_items(pop_items, df, columns,current_user).head(5)
# Out:
#                                                 Name     sub_catagory  \
# 0  Doi Bhetki Recipe - Bengali Style Yogurt Fish ...     Indian Curry
# 1       Beetroot Carrot Tomato & Ginger Juice Recipe        Smoothies
# 2         Carrot and Oats  Whole Wheat Bread Recipe    Homemade Bread
# 3  Chicken Keema Paratha Recipe - Minced Chicken ...     Indian Bread
# 4              Kerala Style Mutton Pepper Fry Recipe  Poriyal Recipes
#
#             Cusine                         Diet  \
# 0  Bengali Recipes  High Protein Non Vegetarian
# 1      Continental                   Vegetarian
# 2      Continental                   Eggetarian
# 3          Mughlai  High Protein Non Vegetarian
# 4   Kerala Recipes               Non Vegeterian
#
#                               comment
# 0  Popular dishes among similar users
# 1  Popular dishes among similar users
# 2  Popular dishes among similar users
# 3  Popular dishes among similar users
# 4  Popular dishes among similar users
